# %%
# !pip install git+https://github.com/Shafi2016/pymodeltime.git
# Out:
# Collecting git+https://github.com/Shafi2016/pymodeltime.git
#   Cloning https://github.com/Shafi2016/pymodeltime.git to /tmp/pip-req-build-j6_sbwge
#   Running command git clone --filter=blob:none --quiet https://github.com/Shafi2016/pymodeltime.git /tmp/pip-req-build-j6_sbwge
#   Resolved https://github.com/Shafi2016/pymodeltime.git to commit 92715e3733d68c5e4d39f1c4d52a19364076bbdb
#   Preparing metadata (setup.py) ... done
# Collecting pystan~=2.19.1.1 (from pymodeltime==0.1)
#   Downloading pystan-2.19.1.1.tar.gz (16.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.2/16.2 MB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: prophet in /usr/local/lib/python3.10/dist-packages (from pymodeltime==0.1) (1.1.5)
# Collecting pmdarima (from pymodeltime==0.1)
#   Downloading pmdarima-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 43.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pymodeltime==0.1) (1.5.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from pymodeltime==0.1) (0.14.1)
# Collecting pytimetk (from pymodeltime==0.1)
#   Downloading pytimetk-0.2.1-py3-none-any.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (from pymodeltime==0.1) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pymodeltime==0.1) (1.2.2)
# Collecting h2o (from pymodeltime==0.1)
#   Downloading h2o-3.44.0.3.tar.gz (265.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.2/265.2 MB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Cython!=0.25.1,>=0.22 in /usr/local/lib/python3.10/dist-packages (from pystan~=2.19.1.1->pymodeltime==0.1) (3.0.6)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.10/dist-packages (from pystan~=2.19.1.1->pymodeltime==0.1) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from h2o->pymodeltime==0.1) (2.31.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from h2o->pymodeltime==0.1) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pymodeltime==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pymodeltime==0.1) (2023.3.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pmdarima->pymodeltime==0.1) (1.3.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima->pymodeltime==0.1) (1.11.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima->pymodeltime==0.1) (2.0.7)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.10/dist-packages (from pmdarima->pymodeltime==0.1) (67.7.2)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pmdarima->pymodeltime==0.1) (23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pymodeltime==0.1) (3.2.0)
# Requirement already satisfied: patsy>=0.5.4 in /usr/local/lib/python3.10/dist-packages (from statsmodels->pymodeltime==0.1) (0.5.4)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet->pymodeltime==0.1) (1.2.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from prophet->pymodeltime==0.1) (3.7.1)
# Requirement already satisfied: holidays>=0.25 in /usr/local/lib/python3.10/dist-packages (from prophet->pymodeltime==0.1) (0.38)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from prophet->pymodeltime==0.1) (4.66.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet->pymodeltime==0.1) (6.1.1)
# Collecting holidays>=0.25 (from prophet->pymodeltime==0.1)
#   Downloading holidays-0.33-py3-none-any.whl (759 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 759.7/759.7 kB 42.6 MB/s eta 0:00:00
# Collecting matplotlib>=2.0.0 (from prophet->pymodeltime==0.1)
#   Downloading matplotlib-3.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 57.6 MB/s eta 0:00:00
# Collecting pandas-flavor<0.7.0,>=0.6.0 (from pytimetk->pymodeltime==0.1)
#   Downloading pandas_flavor-0.6.0-py3-none-any.whl (7.2 kB)
# Collecting pathos<0.4.0,>=0.3.1 (from pytimetk->pymodeltime==0.1)
#   Downloading pathos-0.3.1-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 11.1 MB/s eta 0:00:00
# Collecting plotly<6.0.0,>=5.17.0 (from pytimetk->pymodeltime==0.1)
#   Downloading plotly-5.18.0-py3-none-any.whl (15.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 19.7 MB/s eta 0:00:00
# Requirement already satisfied: plotnine<0.13.0,>=0.12.3 in /usr/local/lib/python3.10/dist-packages (from pytimetk->pymodeltime==0.1) (0.12.4)
# Collecting polars>=0.19.8 (from pytimetk->pymodeltime==0.1)
#   Downloading polars-0.20.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.4/28.4 MB 23.4 MB/s eta 0:00:00
# Collecting pyarrow<14.0.0,>=13.0.0 (from pytimetk->pymodeltime==0.1)
#   Downloading pyarrow-13.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 MB 11.7 MB/s eta 0:00:00
# Collecting tsfeatures<0.5.0,>=0.4.5 (from pytimetk->pymodeltime==0.1)
#   Downloading tsfeatures-0.4.5-py3-none-any.whl (28 kB)
# Requirement already satisfied: stanio~=0.3.0 in /usr/local/lib/python3.10/dist-packages (from cmdstanpy>=1.0.4->prophet->pymodeltime==0.1) (0.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet->pymodeltime==0.1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet->pymodeltime==0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet->pymodeltime==0.1) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet->pymodeltime==0.1) (1.4.5)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet->pymodeltime==0.1) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet->pymodeltime==0.1) (3.1.1)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from pandas-flavor<0.7.0,>=0.6.0->pytimetk->pymodeltime==0.1) (2023.7.0)
# Collecting ppft>=1.7.6.7 (from pathos<0.4.0,>=0.3.1->pytimetk->pymodeltime==0.1)
#   Downloading ppft-1.7.6.7-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 7.3 MB/s eta 0:00:00
# Collecting dill>=0.3.7 (from pathos<0.4.0,>=0.3.1->pytimetk->pymodeltime==0.1)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.7 MB/s eta 0:00:00
# Collecting pox>=0.3.3 (from pathos<0.4.0,>=0.3.1->pytimetk->pymodeltime==0.1)
#   Downloading pox-0.3.3-py3-none-any.whl (29 kB)
# Collecting multiprocess>=0.70.15 (from pathos<0.4.0,>=0.3.1->pytimetk->pymodeltime==0.1)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.4->statsmodels->pymodeltime==0.1) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly<6.0.0,>=5.17.0->pytimetk->pymodeltime==0.1) (8.2.3)
# Requirement already satisfied: mizani<0.10.0,>0.9.0 in /usr/local/lib/python3.10/dist-packages (from plotnine<0.13.0,>=0.12.3->pytimetk->pymodeltime==0.1) (0.9.3)
# Collecting antropy>=0.1.4 (from tsfeatures<0.5.0,>=0.4.5->pytimetk->pymodeltime==0.1)
#   Downloading antropy-0.1.6.tar.gz (17 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting arch>=4.11 (from tsfeatures<0.5.0,>=0.4.5->pytimetk->pymodeltime==0.1)
#   Downloading arch-6.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.7/981.7 kB 63.0 MB/s eta 0:00:00
# Collecting supersmoother>=0.4 (from tsfeatures<0.5.0,>=0.4.5->pytimetk->pymodeltime==0.1)
#   Downloading supersmoother-0.4.tar.gz (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 25.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->h2o->pymodeltime==0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->h2o->pymodeltime==0.1) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->h2o->pymodeltime==0.1) (2023.11.17)
# Requirement already satisfied: numba>=0.57 in /usr/local/lib/python3.10/dist-packages (from antropy>=0.1.4->tsfeatures<0.5.0,>=0.4.5->pytimetk->pymodeltime==0.1) (0.58.1)
# Collecting stochastic (from antropy>=0.1.4->tsfeatures<0.5.0,>=0.4.5->pytimetk->pymodeltime==0.1)
#   Downloading stochastic-0.7.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.57->antropy>=0.1.4->tsfeatures<0.5.0,>=0.4.5->pytimetk->pymodeltime==0.1) (0.41.1)
# Building wheels for collected packages: pymodeltime, pystan, h2o, antropy, supersmoother
#   Building wheel for pymodeltime (setup.py) ... done
#   Created wheel for pymodeltime: filename=pymodeltime-0.1-py3-none-any.whl size=19182 sha256=b11bf8d4a8e74c6c0ce022dee9748cbec1bc66920816bb840cfcaa228483fc51
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a46_20af/wheels/bc/fd/07/a54a41143922e3958b759f2d5063c5f84ef4051fb0fbd4669a
#   Building wheel for pystan (setup.py) ... done
#   Created wheel for pystan: filename=pystan-2.19.1.1-cp310-cp310-linux_x86_64.whl size=61976192 sha256=904d9adf516bc472b8d4fbc83117cbdedcdf876310b7809d77f82abd60b3b832
#   Stored in directory: /root/.cache/pip/wheels/3d/1c/94/4516243362eedbedad15ac4389691ee3bf2d45bec2639c9d8b
#   Building wheel for h2o (setup.py) ... done
#   Created wheel for h2o: filename=h2o-3.44.0.3-py2.py3-none-any.whl size=265293968 sha256=401530abd36da52ec8914d397ac562b94e9b6d656338f4bc09a84472cd5f1eed
#   Stored in directory: /root/.cache/pip/wheels/77/9a/1c/2da26f943fd46b57f3c20b54847b936b9152b831dc7447cf71
#   Building wheel for antropy (pyproject.toml) ... done
#   Created wheel for antropy: filename=antropy-0.1.6-py3-none-any.whl size=16880 sha256=981c91c357f4139cf5c5d0825795395ac8c17f85081bf9747956d658f6f4bfff
#   Stored in directory: /root/.cache/pip/wheels/98/22/06/e91d7bb213c7133d5e2eb34258623e1e19928d5f05e1ee6812
#   Building wheel for supersmoother (setup.py) ... done
#   Created wheel for supersmoother: filename=supersmoother-0.4-py3-none-any.whl size=16145 sha256=669235dc24980e217ef22b7aec8f5b443d2954daf17ccee3002acb2bfe013704
#   Stored in directory: /root/.cache/pip/wheels/cf/6a/f2/3d545d90957029bf34179d21e077f84eeb96d7dfe668268494
# Successfully built pymodeltime pystan h2o antropy supersmoother
# Installing collected packages: supersmoother, pystan, pyarrow, ppft, pox, polars, plotly, dill, stochastic, multiprocess, matplotlib, holidays, h2o, pathos, antropy, pmdarima, pandas-flavor, arch, tsfeatures, pytimetk, pymodeltime
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 10.0.1
#     Uninstalling pyarrow-10.0.1:
#       Successfully uninstalled pyarrow-10.0.1
#   Attempting uninstall: polars
#     Found existing installation: polars 0.17.3
#     Uninstalling polars-0.17.3:
#       Successfully uninstalled polars-0.17.3
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.15.0
#     Uninstalling plotly-5.15.0:
#       Successfully uninstalled plotly-5.15.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: holidays
#     Found existing installation: holidays 0.38
#     Uninstalling holidays-0.38:
#       Successfully uninstalled holidays-0.38
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# ibis-framework 6.2.0 requires pyarrow<13,>=2, but you have pyarrow 13.0.0 which is incompatible.
# Successfully installed antropy-0.1.6 arch-6.2.0 dill-0.3.7 h2o-3.44.0.3 holidays-0.33 matplotlib-3.8.2 multiprocess-0.70.15 pandas-flavor-0.6.0 pathos-0.3.1 plotly-5.18.0 pmdarima-2.0.4 polars-0.20.2 pox-0.3.3 ppft-1.7.6.7 pyarrow-13.0.0 pymodeltime-0.1 pystan-2.19.1.1 pytimetk-0.2.1 stochastic-0.7.0 supersmoother-0.4 tsfeatures-0.4.5

# %%
import pandas as pd
import pytimetk as tk
from sklearn.model_selection import train_test_split

# %%
# Load data
data = pd.read_csv('./m_qdata.csv')
data['date'] = pd.to_datetime(data['date'])
data.head(3)
# Out:
#         date       GDP      GDPM  EMP_CONS_CAN  TOT_HRS_CAN   NDM_new  \
# 0 1981-04-01  0.011177  0.006170      0.011605     0.004021  0.010748
# 1 1981-07-01 -0.009018 -0.009057      0.002623    -0.001366 -0.033847
# 2 1981-10-01 -0.004589 -0.000361     -0.011007    -0.008744 -0.024493
#
#      IP_new  MANU_TOT_INV_new    RT_new  IMP_TRANSP_BP_new  EMP_SALES_CAN
# 0  0.010193          0.036455  0.001205           0.080797       0.000057
# 1 -0.017778          0.035141 -0.008642           0.028632       0.008603
# 2 -0.024728          0.029451 -0.027613          -0.123275       0.009392

# %%
# Get the maximum (last) date in your dataset
max_date = data['date'].max()

# Create a DataFrame with only the last date
last_date_df = pd.DataFrame({'date': [max_date]})

# Extend this DataFrame with 6 future dates
future_dates = last_date_df.future_frame(
    date_column='date',
    length_out=6,  # Number of future periods to forecast
    freq='Q',
    bind_data=False # Do not combine the original data
)
# Append these future dates to your original data
extended_data = pd.concat([data, future_dates]).reset_index(drop=True)

# Specify value columns for which you want to create lags
all_columns = data.columns.tolist()
excluded_columns = ['date','GDP']  # Add any other columns you want to exclude
value_columns = [col for col in all_columns if col not in excluded_columns]


# Create lagged columns for the extended data
lagged_data = extended_data.augment_lags(
    date_column='date',
    value_column= value_columns ,
    lags=6,  # Creating a 6-period lag
    engine='pandas'
)

# Drop the original value columns
lagged_data.drop(value_columns, axis=1, inplace=True)

lagged_data.to_csv("./data_with_future_and_lags.csv", index = False)

# %%
# Drop all rows with any NaN values in lagged_data
full_data = lagged_data.dropna()

# Save the resulting DataFrame to a CSV file
full_data.to_csv("./full_data.csv", index=False)

# Specify value columns for which you want to create lags
all_columns_2 = full_data.columns.tolist()
excluded_columns = ['date','GDP']  # Add any other columns you want to exclude
columns_to_convert = [col for col in all_columns_2 if col not in excluded_columns]


full_data [columns_to_convert] = full_data [columns_to_convert].astype('float32')
train_data, test_data = train_test_split(full_data, test_size=0.2, shuffle=False)

# Drop all rows with any NaN values in train_data and test_data
train_data = train_data.dropna()
test_data = test_data.dropna()

# Ensure the date column is in datetime format
train_data['date'] = pd.to_datetime(train_data['date'])
test_data['date'] = pd.to_datetime(test_data['date'])

# %%
lagged_columns = [
    'GDPM_lag_6', 'EMP_CONS_CAN_lag_6', 'TOT_HRS_CAN_lag_6',
    'NDM_new_lag_6', 'IP_new_lag_6', 'MANU_TOT_INV_new_lag_6',
    'RT_new_lag_6', 'IMP_TRANSP_BP_new_lag_6', 'EMP_SALES_CAN_lag_6'
]

# Check that all lagged columns are not NaN
non_nan_conditions = [lagged_data[col].notna() for col in lagged_columns]
combined_condition = pd.concat(non_nan_conditions, axis=1).all(axis=1)

# Filter rows where 'value' is NaN but lagged columns are not NaN
future_data = lagged_data[lagged_data['GDP'].isna() & combined_condition]
future_data[columns_to_convert] = future_data[columns_to_convert].astype('float32')

# %%
train_data.head(3)
# Out:
#         date       GDP  GDPM_lag_6  EMP_CONS_CAN_lag_6  TOT_HRS_CAN_lag_6  \
# 6 1982-10-01 -0.009270    0.006172            0.011604           0.004021
# 7 1983-01-01  0.016586   -0.009056            0.002623          -0.001366
# 8 1983-04-01  0.019470   -0.000361           -0.011009          -0.008743
#
#    NDM_new_lag_6  IP_new_lag_6  MANU_TOT_INV_new_lag_6  RT_new_lag_6  \
# 6       0.010750      0.010193                0.036469      0.001205
# 7      -0.033844     -0.017776                0.035156     -0.008644
# 8      -0.024490     -0.024734                0.029449     -0.027618
#
#    IMP_TRANSP_BP_new_lag_6  EMP_SALES_CAN_lag_6
# 6                 0.080811             0.000057
# 7                 0.028625             0.008606
# 8                -0.123291             0.009392

# %%
test_data.head(3)
# Out:
#           date       GDP  GDPM_lag_6  EMP_CONS_CAN_lag_6  TOT_HRS_CAN_lag_6  \
# 130 2013-10-01  0.010452    0.005360            0.014954           0.007828
# 131 2014-01-01  0.001633    0.001907            0.001413           0.003014
# 132 2014-04-01  0.009094    0.002270            0.001864          -0.000572
#
#      NDM_new_lag_6  IP_new_lag_6  MANU_TOT_INV_new_lag_6  RT_new_lag_6  \
# 130      -0.005383      0.000440                0.009277     -0.002390
# 131      -0.002430     -0.015671                0.005211      0.004482
# 132      -0.005245     -0.000548                0.003248      0.009583
#
#      IMP_TRANSP_BP_new_lag_6  EMP_SALES_CAN_lag_6
# 130                 0.034393             0.002655
# 131                -0.027817            -0.004276
# 132                -0.028305             0.009865

# %%
future_data.head()
# Out:
#           date  GDP  GDPM_lag_6  EMP_CONS_CAN_lag_6  TOT_HRS_CAN_lag_6  \
# 162 2021-12-31  NaN   -0.115417           -0.178589          -0.194702
# 163 2022-03-31  NaN    0.084290            0.089661           0.156128
# 164 2022-06-30  NaN    0.020035            0.016296           0.036652
# 165 2022-09-30  NaN    0.012665            0.041565           0.026901
# 166 2022-12-31  NaN   -0.002768           -0.008064          -0.009727
#
#      NDM_new_lag_6  IP_new_lag_6  MANU_TOT_INV_new_lag_6  RT_new_lag_6  \
# 162      -0.115845     -0.134033               -0.019272     -0.122375
# 163       0.100037      0.074707               -0.011368      0.165527
# 164       0.027435      0.028366                0.007206      0.026596
# 165      -0.010002      0.017288                0.021072      0.012741
# 166      -0.001701     -0.005859                0.022888     -0.025757
#
#      IMP_TRANSP_BP_new_lag_6  EMP_SALES_CAN_lag_6
# 162                -1.026367            -0.141846
# 163                 1.010742             0.117554
# 164                 0.016296             0.022964
# 165                -0.056763            -0.017380
# 166                -0.164673             0.008980

# %%
# Define the target column
target_column = 'GDP'

# Select feature columns - all columns except 'date', 'value', and 'id'
feature_columns = [col for col in train_data.columns if col not in ['date', target_column, 'id']]

# Extract features (X) and target (y) from the training data
X_train = train_data[feature_columns]
y_train = train_data[target_column]

# Display the first few rows of X_train to verify
print(X_train.head())
# Out:
#     GDPM_lag_6  EMP_CONS_CAN_lag_6  TOT_HRS_CAN_lag_6  NDM_new_lag_6  \
# 6     0.006172            0.011604           0.004021       0.010750
# 7    -0.009056            0.002623          -0.001366      -0.033844
# 8    -0.000361           -0.011009          -0.008743      -0.024490
# 9    -0.007881           -0.032501          -0.013840      -0.026245
# 10   -0.013107           -0.043640          -0.020737      -0.031189
#
#     IP_new_lag_6  MANU_TOT_INV_new_lag_6  RT_new_lag_6  \
# 6       0.010193                0.036469      0.001205
# 7      -0.017776                0.035156     -0.008644
# 8      -0.024734                0.029449     -0.027618
# 9      -0.014992                0.031219     -0.021988
# 10     -0.036621               -0.006004     -0.035156
#
#     IMP_TRANSP_BP_new_lag_6  EMP_SALES_CAN_lag_6
# 6                  0.080811             0.000057
# 7                  0.028625             0.008606
# 8                 -0.123291             0.009392
# 9                 -0.056488            -0.010925
# 10                 0.118958            -0.006973

# %%
from pymodeltime import ArimaReg, ProphetReg
from pymodeltime import ModelTimeTable, ModelTimeAccuracy, ModelTimeCalibration, ModelTimeForecast
from pymodeltime import ArimaReg, ProphetReg
from pymodeltime import MLModelWrapper,H2OAutoMLWrapper

from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %%
# Create instances of the ML models
rf_model = RandomForestRegressor()
ml_rf_wrapper = MLModelWrapper(rf_model, feature_columns, "Random Forest")

xgb_model = XGBRegressor()
ml_xgb_wrapper = MLModelWrapper(xgb_model, feature_columns, "XGBoost")

# Fit the models (assuming train_data and y_train are defined)
ml_rf_wrapper.fit(train_data, y_train)
ml_xgb_wrapper.fit(train_data, y_train)

# %%
from sklearn.model_selection import GridSearchCV

def tune_rf_model(X, y, param_grid, cv=5):
    rf_model = RandomForestRegressor()
    grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=cv, scoring='neg_mean_squared_error', verbose=1, n_jobs=-1)
    grid_search.fit(X, y)
    return grid_search.best_estimator_

def tune_xgb_model(X, y, param_grid, cv=5):
    xgb_model = XGBRegressor()
    grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid, cv=cv, scoring='neg_mean_squared_error', verbose=1, n_jobs=-1)
    grid_search.fit(X, y)
    return grid_search.best_estimator_


rf_param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

xgb_param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [3, 6],
    'learning_rate': [0.01, 0.1],
    'subsample': [0.8, 1]
}


# Assuming train_data and y_train are defined
# Extract features and target
X_train = train_data[feature_columns]
y_train = train_data[target_column]

# Tune and fit Random Forest
fine_tuned_rf = tune_rf_model(X_train, y_train, rf_param_grid)
ml_rf_wrapper = MLModelWrapper(fine_tuned_rf, feature_columns, "Random Forest")
ml_rf_wrapper.fit(X_train, y_train)

# Tune and fit XGBoost
fine_tuned_xgb = tune_xgb_model(X_train, y_train, xgb_param_grid)
ml_xgb_wrapper = MLModelWrapper(fine_tuned_xgb, feature_columns, "XGBoost")
ml_xgb_wrapper.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Fitting 5 folds for each of 16 candidates, totalling 80 fits

# %%
import h2o
from h2o.automl import H2OAutoML

h2o.init()

# Convert to H2OFrame and train
h2o_train = h2o.H2OFrame(train_data)
automl = H2OAutoML(max_models=10, seed=1, max_runtime_secs=300)
automl.train(x=feature_columns, y='GDP', training_frame=h2o_train)

# Extract the leaderboard
lb = automl.leaderboard

# Optionally, you can convert the leaderboard to a pandas DataFrame for easier manipulation
lb_df = lb.as_data_frame()

# Display the leaderboard
print(lb_df.head())

# Get the best model
best_h2o_model = automl.leader


# Example of model initialization
h2o_automl_wrapper = H2OAutoMLWrapper(best_h2o_model, target_column='GDP')
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  -----------------------------------------------------------------------------------------
# H2O_cluster_uptime:         35 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.44.0.3
# H2O_cluster_version_age:    2 days
# H2O_cluster_name:           H2O_from_python_unknownUser_gkywo6
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.170 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null, "colab_language_server": "/usr/colab/bin/language_service"}
# H2O_internal_security:      False
# Python_version:             3.10.12 final
# --------------------------  -----------------------------------------------------------------------------------------
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |█
# 01:21:28.192: _min_rows param, The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 124.0.
#
# ██████████████████████████████████████████████████████████████| (done) 100%
# Export File progress: |██████████████████████████████████████████████████████████| (done) 100%
#                                             model_id      rmse       mse  \
# 0  StackedEnsemble_AllModels_1_AutoML_1_20231223_...  0.007189  0.000052
# 1                      GLM_1_AutoML_1_20231223_12122  0.007201  0.000052
# 2                      GBM_2_AutoML_1_20231223_12122  0.007245  0.000052
# 3                      GBM_5_AutoML_1_20231223_12122  0.007247  0.000053
# 4  StackedEnsemble_BestOfFamily_1_AutoML_1_202312...  0.007255  0.000053
#
#         mae     rmsle  mean_residual_deviance
# 0  0.005415  0.007166                0.000052
# 1  0.005557  0.007177                0.000052
# 2  0.005597  0.007222                0.000052
# 3  0.005630  0.007222                0.000053
# 4  0.005445  0.007232                0.000053
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  -----------------------------------------------------------------------------------------
# H2O_cluster_uptime:         1 min 05 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.44.0.3
# H2O_cluster_version_age:    2 days
# H2O_cluster_name:           H2O_from_python_unknownUser_gkywo6
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.168 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null, "colab_language_server": "/usr/colab/bin/language_service"}
# H2O_internal_security:      False
# Python_version:             3.10.12 final
# --------------------------  -----------------------------------------------------------------------------------------

# %%
prophet_model_multi  = ProphetReg(seasonality_yearly=True, seasonality_weekly=True,
                               seasonality_daily=False, changepoint_range=0.5, prior_scale_seasonality=5.0,
                               season='multiplicative',interval_width=0.95 )


prophet_model_multi.fit(train_data,
                        target_column='GDP',
                        date_column='date',
                        regressors= feature_columns)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpk9ooz196/6do8m7py.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpk9ooz196/g5kgnsow.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87318', 'data', 'file=/tmp/tmpk9ooz196/6do8m7py.json', 'init=/tmp/tmpk9ooz196/g5kgnsow.json', 'output', 'file=/tmp/tmpk9ooz196/prophet_model1wnohw4z/prophet_model-20231223012306.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:23:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:23:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# Add it to ModelTimeTable
modeltime_table = ModelTimeTable(ml_xgb_wrapper,
                                 ml_rf_wrapper,h2o_automl_wrapper,
                                   prophet_model_multi)

# %%
model_time_calibrator = ModelTimeCalibration(modeltime_table, test_data)
model_time_calibrator.calibrate()
calibration_results_df = model_time_calibrator.get_calibration_results()
print(calibration_results_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-061cc6ea038b> in <cell line: 2>()
#       1 model_time_calibrator = ModelTimeCalibration(modeltime_table, test_data)
# ----> 2 model_time_calibrator.calibrate()
#       3 calibration_results_df = model_time_calibrator.get_calibration_results()
#       4 print(calibration_results_df)
#
# /usr/local/lib/python3.10/dist-packages/pymodeltime/ModelTimeCalibration.py in calibrate(self)
#      34             elif isinstance(model, MLModelWrapper):
#      35                 # Calibration for ML models wrapped in MLModelWrapper
# ---> 36                 self._calibrate_ml_model(model)
#      37             elif isinstance(model, H2OAutoMLWrapper):
#      38                 # Special handling for H2O AutoML model
#
# /usr/local/lib/python3.10/dist-packages/pymodeltime/ModelTimeCalibration.py in _calibrate_ml_model(self, model)
#      98     def _calibrate_ml_model(self, model):
#      99           X = self.new_data[model.feature_names]
# --> 100           y = self.new_data['value']
#     101
#     102           predictions = model.predict(X)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'value'
